# %%
from pre_process_messages import extract_messages

extract_messages(
    input_path = "./2025-11-13_on_boarding_messages/2025-11-13/com.att.aamg.kafka.prod.sms-prod-eastus2-mt-default.csv", 
    output_dir= f"./data/input",
    originator = "24273",
    max_rows = 1_000_000,
    dilute_factor = 10  # write every Nth message
    
)
